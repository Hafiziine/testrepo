# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sanni Afeez Adeyinka**

# %% [markdown]
# I desire to become a data scientist and a software developer

# %% [markdown]
# *I am intrested in data science because it is a field of study that cut across relatively every industry hereby making being a data scientist one of the sexiest job*

# %% [markdown]
# ### The code below will perform basic arithmetic operation

# %%
1+1
# Out:
# 2

# %% [markdown]
# |Gender|Age|Religion|
# |------|---|--------|
# |Male|2|Christianity|

# %% [markdown]
# 1. Category
#     1. first class
#     5. second class
# 5.  Subcategory
#     1. first and second
#     3. third class

# %% [markdown]
# - Category
#     * first class
#     * second class
# -  Subcategory
#     * first and second
#     * third class

# %% [markdown]
# ~abcdefgh~

# %% [markdown]
# ~~adfgh~~

# %% [markdown]
# [facebook home page]("www.facebook.com")
